# %%
import initialize

# %%
import sample
sample.message
# Out:
# 'This is "/Users/wakita/Library/CloudStorage/Dropbox/projects/project_template/src/sample/__init__.py".'

# %%
import os
print(os.environ['HOME'])

os.chdir('..')
print(os.getcwd())
# Out:
# hoge
# /Users/wakita/Library/CloudStorage/Dropbox/projects/project_template

# %%
from sample.spi import get_spi_data

df = get_spi_data(year=2023)
df
# Out:
#                              Country SPI country code  Social Progress Index  \
# 0                              World              WWW                  63.44
# 13                       Afghanistan              AFG                  32.15
# 26                           Albania              ALB                  71.70
# 39                           Algeria              DZA                  64.22
# 52                            Angola              AGO                  43.90
# ...                              ...              ...                    ...
# 2496                       St. Lucia              LCA                    NaN
# 2509  St. Vincent and the Grenadines              VCT                    NaN
# 2522                          Taiwan              TWN                    NaN
# 2535                           Tonga              TON                    NaN
# 2548                          Tuvalu              TUV                    NaN
#
# ...

# %%
df.to_csv('out/spi.csv', index=False)
